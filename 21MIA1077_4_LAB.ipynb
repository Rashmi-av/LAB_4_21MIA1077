# %%
import cv2
import numpy as np
import os
from google.colab.patches import cv2_imshow

# %%
def load_video(video_path, resize_dim=(320, 240)):
    cap = cv2.VideoCapture(video_path)
    frames = []

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Resize frame for faster processing
        resized_frame = cv2.resize(frame, resize_dim)
        frames.append(resized_frame)

    cap.release()
    return frames

# %%
def convert_to_hsv(frame):
    return cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

def noise_detection(frame):
    blurred = cv2.GaussianBlur(frame, (5, 5), 0)
    noise_mask = cv2.absdiff(frame, blurred)
    return noise_mask

# %%
def histogram_comparison(frame1, frame2):
    hist1 = cv2.calcHist([frame1], [0, 1], None, [256, 256], [0, 256, 0, 256])
    hist2 = cv2.calcHist([frame2], [0, 1], None, [256, 256], [0, 256, 0, 256])
    cv2.normalize(hist1, hist1, 0, 1, cv2.NORM_MINMAX)
    cv2.normalize(hist2, hist2, 0, 1, cv2.NORM_MINMAX)


    similarity_score = cv2.compareHist(hist1, hist2, cv2.HISTCMP_CORREL)
    return similarity_score

# %%
def sobel_edge_detection(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # Convert to grayscale before Sobel
    sobel_x = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=5)
    sobel_y = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=5)
    edges = cv2.magnitude(sobel_x, sobel_y)
    return np.uint8(edges)

# %%
def find_least_similarity_cuts(similarity_scores, frames, top_n=5):
    # Get the indices of the least similarity scores (lowest values indicate scene cuts)
    least_similar_indices = np.argsort(similarity_scores)[:top_n]

    print(f"Top {top_n} scene cut frames (by least similarity):")
    for i, idx in enumerate(least_similar_indices):
        print(f"Scene cut {i+1}: between frame {idx} and frame {idx+1} with similarity score: {similarity_scores[idx]}")

        # Display the two consecutive frames where the scene cut occurs
        cv2_imshow(frames[idx])
        cv2_imshow(frames[idx+1])
        cv2.waitKey(1000)  # Wait for a key press to display next set of frames

    return least_similar_indices

# %%
def process_video(video_path, hsv_directory, noise_directory, edge_directory, top_n_cuts=5, resize_dim=(320, 240)):
    if not os.path.exists(hsv_directory):
        os.makedirs(hsv_directory)
    if not os.path.exists(noise_directory):
         os.makedirs(noise_directory)
    if not os.path.exists(edge_directory):
         os.makedirs(edge_directory)

    frames = load_video(video_path, resize_dim=resize_dim)
    hsv_frames = []
    noise_frames = []
    edge_frames = []
    similarity_scores = []

    for idx, frame in enumerate(frames):
        # Step 2: Convert each frame into HSV
        hsv_frame = convert_to_hsv(frame)
        hsv_frames.append(hsv_frame)
        cv2.imwrite(os.path.join(hsv_directory, f'hsv_frame_{idx}.png'), hsv_frame)

        # Step 3: Detect noise
        noise_frame = noise_detection(frame)
        noise_frames.append(noise_frame)
        cv2.imwrite(os.path.join(noise_directory, f'noise_frame_{idx}.png'), noise_frame)

        # Step 4: Perform histogram comparison with the previous frame
        if idx > 0:
            similarity = histogram_comparison(frames[idx-1], frames[idx])
            similarity_scores.append(similarity)
            print(f'Similarity between frame {idx-1} and frame {idx}: {similarity}')

        # Step 5: Perform edge detection
        edge_frame = sobel_edge_detection(frame)
        edge_frames.append(edge_frame)
        cv2.imwrite(os.path.join(edge_directory, f'edge_frame_{idx}.png'), edge_frame)

    # Step 6: Find least similarity cuts and display the frames
    if len(similarity_scores) > 0:
        least_similar_indices = find_least_similarity_cuts(similarity_scores, frames, top_n_cuts)

        # Optionally, save the frames at the scene cut points for analysis
        for i, idx in enumerate(least_similar_indices):
            cv2.imwrite(os.path.join(hsv_directory, f'scene_cut_frame_{i+1}frame{idx}.png'), frames[idx])
            cv2.imwrite(os.path.join(hsv_directory, f'scene_cut_frame_{i+1}frame{idx+1}.png'), frames[idx+1])

# %%
video_path = r"/content/rashmi.mp4"
hsv_directory = r"/content/hsv_frames"
noise_directory = r"/content/noise_frames"
edge_directory = r"/content/edge_frames"
process_video(video_path, hsv_directory, noise_directory, edge_directory, top_n_cuts=5, resize_dim=(320, 240))
# Out:
# Similarity between frame 0 and frame 1: 0.996969620998848
# Similarity between frame 1 and frame 2: 0.9975432345247928
# Similarity between frame 2 and frame 3: 0.9930420208763923
# Similarity between frame 3 and frame 4: 0.9951622503577263
# Similarity between frame 4 and frame 5: 0.9638997884708354
# Similarity between frame 5 and frame 6: 0.996639621958274
# Similarity between frame 6 and frame 7: 0.9955526042234528
# Similarity between frame 7 and frame 8: 0.9953063937961105
# Similarity between frame 8 and frame 9: 0.98850486100381
# Similarity between frame 9 and frame 10: 0.9948829416686703
# Similarity between frame 10 and frame 11: 0.996072625938158
# Similarity between frame 11 and frame 12: 0.994848251748762
# Similarity between frame 12 and frame 13: 0.980645297751961
# Similarity between frame 13 and frame 14: 0.9950445597634341
# Similarity between frame 14 and frame 15: 0.9930785335395873
# Similarity between frame 15 and frame 16: 0.9932246510214099
# Similarity between frame 16 and frame 17: 0.9862250274084435
# Similarity between frame 17 and frame 18: 0.995314295492462
# Similarity between frame 18 and frame 19: 0.9946851129632043
# Similarity between frame 19 and frame 20: 0.9931954625887649
# Similarity between frame 20 and frame 21: 0.9922303826368025
# Similarity between frame 21 and frame 22: 0.9947011254722467
# Similarity between frame 22 and frame 23: 0.9901821096114954
# Similarity between frame 23 and frame 24: 0.9952600587639224
# Similarity between frame 24 and frame 25: 0.9938774615498965
# Similarity between frame 25 and frame 26: 0.9931994939312461
# Similarity between frame 26 and frame 27: 0.9919500002872853
# Similarity between frame 27 and frame 28: 0.9940361237422688
# Similarity between frame 28 and frame 29: 0.9966929344834513
# Similarity between frame 29 and frame 30: 0.9909928765182632
# Similarity between frame 30 and frame 31: 0.9952193790873903
# Similarity between frame 31 and frame 32: 0.9971775649132218
# Similarity between frame 32 and frame 33: 0.9961126771982708
# Similarity between frame 33 and frame 34: 0.9959388910004779
# Similarity between frame 34 and frame 35: 0.9933272981960211
# Similarity between frame 35 and frame 36: 0.9960233180289639
# Similarity between frame 36 and frame 37: 0.9958691636120582
# Similarity between frame 37 and frame 38: 0.9955222687895087
# Similarity between frame 38 and frame 39: 0.9945239051199471
# Similarity between frame 39 and frame 40: 0.995505386044218
# Similarity between frame 40 and frame 41: 0.9952727395372658
# Similarity between frame 41 and frame 42: 0.995114340895396
# Similarity between frame 42 and frame 43: 0.9947734195932916
# Similarity between frame 43 and frame 44: 0.9952611063728843
# Similarity between frame 44 and frame 45: 0.996031628904104
# Similarity between frame 45 and frame 46: 0.9957448400159663
# Similarity between frame 46 and frame 47: 0.9943638047283434
# Similarity between frame 47 and frame 48: 0.9960284694478182
# Similarity between frame 48 and frame 49: 0.996362938535357
# Similarity between frame 49 and frame 50: 0.9951475575774502
# Similarity between frame 50 and frame 51: 0.9942403195873004
# Similarity between frame 51 and frame 52: 0.9961496034522486
# Similarity between frame 52 and frame 53: 0.9964164137587508
# Similarity between frame 53 and frame 54: 0.9952109089688411
# Similarity between frame 54 and frame 55: 0.9925865588490722
# Similarity between frame 55 and frame 56: 0.9953377523411441
# Similarity between frame 56 and frame 57: 0.9967131500772686
# Similarity between frame 57 and frame 58: 0.9957509016945245
# Similarity between frame 58 and frame 59: 0.9960404738244736
# Similarity between frame 59 and frame 60: 0.9951818048865255
# Similarity between frame 60 and frame 61: 0.9970997046032833
# Similarity between frame 61 and frame 62: 0.9974616562342444
# Similarity between frame 62 and frame 63: 0.995889422720882
# Similarity between frame 63 and frame 64: 0.9963535690604116
# Similarity between frame 64 and frame 65: 0.9956974182247345
# Similarity between frame 65 and frame 66: 0.9956376824501056
# Similarity between frame 66 and frame 67: 0.9958023357901902
# Similarity between frame 67 and frame 68: 0.9941827154386069
# Similarity between frame 68 and frame 69: 0.9934480171628141
# Similarity between frame 69 and frame 70: 0.9944023248575066
# Similarity between frame 70 and frame 71: 0.9940353260353907
# Similarity between frame 71 and frame 72: 0.9930435569003001
# Similarity between frame 72 and frame 73: 0.9929122659319711
# Similarity between frame 73 and frame 74: 0.994515243143688
# Similarity between frame 74 and frame 75: 0.9927249522581951
# Similarity between frame 75 and frame 76: 0.9895297277975966
# Similarity between frame 76 and frame 77: 0.9918455138766176
# Similarity between frame 77 and frame 78: 0.9939671765535383
# Similarity between frame 78 and frame 79: 0.9961982803735719
# Similarity between frame 79 and frame 80: 0.9955323365968487
# Similarity between frame 80 and frame 81: 0.9952363518512127
# Similarity between frame 81 and frame 82: 0.9960994991168909
# Similarity between frame 82 and frame 83: 0.9965203427062853
# Similarity between frame 83 and frame 84: 0.9951127152819654
# Similarity between frame 84 and frame 85: 0.9951197558824438
# Similarity between frame 85 and frame 86: 0.9962938866649874
# Similarity between frame 86 and frame 87: 0.9968188305728523
# Similarity between frame 87 and frame 88: 0.9955608542344184
# Similarity between frame 88 and frame 89: 0.9962745976596298
# Similarity between frame 89 and frame 90: 0.9940664415924773
# Similarity between frame 90 and frame 91: 0.9973320888921368
# Similarity between frame 91 and frame 92: 0.9978913501586882
# Similarity between frame 92 and frame 93: 0.9961569573400885
# Similarity between frame 93 and frame 94: 0.9957125270559645
# Similarity between frame 94 and frame 95: 0.9957259385417816
# Similarity between frame 95 and frame 96: 0.9951803411270211
# Similarity between frame 96 and frame 97: 0.995507841464341
# Similarity between frame 97 and frame 98: 0.9948056341571883
# Similarity between frame 98 and frame 99: 0.9951807878371545
# Similarity between frame 99 and frame 100: 0.9955487004620199
# Similarity between frame 100 and frame 101: 0.9953057795873196
# Similarity between frame 101 and frame 102: 0.9962363622385476
# Similarity between frame 102 and frame 103: 0.995975585911318
# Similarity between frame 103 and frame 104: 0.9956879272088882
# Similarity between frame 104 and frame 105: 0.9957948721778627
# Similarity between frame 105 and frame 106: 0.9967755294825803
# Similarity between frame 106 and frame 107: 0.9967801580772242
# Similarity between frame 107 and frame 108: 0.99547452865052
# Similarity between frame 108 and frame 109: 0.9951450619286459
# Similarity between frame 109 and frame 110: 0.996548000788115
# Similarity between frame 110 and frame 111: 0.9959760725291817
# Similarity between frame 111 and frame 112: 0.9961507457091316
# Similarity between frame 112 and frame 113: 0.9948550940076074
# Similarity between frame 113 and frame 114: 0.9964253168541946
# Similarity between frame 114 and frame 115: 0.9969803377335472
# Similarity between frame 115 and frame 116: 0.9954971349783517
# Similarity between frame 116 and frame 117: 0.9952114483197482
# Similarity between frame 117 and frame 118: 0.9962407230930224
# Similarity between frame 118 and frame 119: 0.9961968043431705
# Similarity between frame 119 and frame 120: 0.9921363842228803
# Similarity between frame 120 and frame 121: 0.9959198156079284
# Similarity between frame 121 and frame 122: 0.9979165135561376
# Similarity between frame 122 and frame 123: 0.9969490042322848
# Similarity between frame 123 and frame 124: 0.9955810322984842
# Similarity between frame 124 and frame 125: 0.9948756793103322
# Similarity between frame 125 and frame 126: 0.9958363204136164
# Similarity between frame 126 and frame 127: 0.9971434323218842
# Similarity between frame 127 and frame 128: 0.9928110160017386
# Similarity between frame 128 and frame 129: 0.9949709906188137
# Similarity between frame 129 and frame 130: 0.9967961826863311
# Similarity between frame 130 and frame 131: 0.9966550640142672
# Similarity between frame 131 and frame 132: 0.9957912837513336
# Similarity between frame 132 and frame 133: 0.9963647416156973
# Similarity between frame 133 and frame 134: 0.9977221398568998
# Similarity between frame 134 and frame 135: 0.9971053920125187
# Similarity between frame 135 and frame 136: 0.9964456635904589
# Similarity between frame 136 and frame 137: 0.995381908015397
# Similarity between frame 137 and frame 138: 0.997413229132921
# Similarity between frame 138 and frame 139: 0.9968689620955391
# Similarity between frame 139 and frame 140: 0.9963301859252895
# Similarity between frame 140 and frame 141: 0.9943332721882439
# Similarity between frame 141 and frame 142: 0.9960778162426948
# Similarity between frame 142 and frame 143: 0.9961415654186085
# Similarity between frame 143 and frame 144: 0.9953780912199245
# Similarity between frame 144 and frame 145: 0.9933190130541172
# Similarity between frame 145 and frame 146: 0.994654890321321
# Similarity between frame 146 and frame 147: 0.9966974677324599
# Similarity between frame 147 and frame 148: 0.9946734291833434
# Similarity between frame 148 and frame 149: 0.99664169672633
# Similarity between frame 149 and frame 150: 0.9934769842449918
# Similarity between frame 150 and frame 151: 0.996832064083678
# Similarity between frame 151 and frame 152: 0.9919812883660296
# Similarity between frame 152 and frame 153: 0.9914315658579217
# Similarity between frame 153 and frame 154: 0.9948114556841955
# Similarity between frame 154 and frame 155: 0.9957031709800103
# Similarity between frame 155 and frame 156: 0.9942632978368825
# Similarity between frame 156 and frame 157: 0.9936523357393193
# Similarity between frame 157 and frame 158: 0.9959897485416885
# Similarity between frame 158 and frame 159: 0.9964740171290274
# Similarity between frame 159 and frame 160: 0.9947409099945816
# Similarity between frame 160 and frame 161: 0.9918604065835968
# Similarity between frame 161 and frame 162: 0.9947584718683312
# Similarity between frame 162 and frame 163: 0.9956233047904152
# Similarity between frame 163 and frame 164: 0.9937140891154528
# Similarity between frame 164 and frame 165: 0.994383715848723
# Similarity between frame 165 and frame 166: 0.995338485360862
# Similarity between frame 166 and frame 167: 0.9964002072076709
# Similarity between frame 167 and frame 168: 0.9945273390702273
# Similarity between frame 168 and frame 169: 0.9927131273150954
# Similarity between frame 169 and frame 170: 0.9949236436576054
# Similarity between frame 170 and frame 171: 0.995801783312439
# Similarity between frame 171 and frame 172: 0.994718576626159
# Similarity between frame 172 and frame 173: 0.9943403945603573
# Similarity between frame 173 and frame 174: 0.9951309827795038
# Similarity between frame 174 and frame 175: 0.99565376063758
# Similarity between frame 175 and frame 176: 0.9949640565546537
# Similarity between frame 176 and frame 177: 0.9923188177437285
# Similarity between frame 177 and frame 178: 0.9930002376662808
# Similarity between frame 178 and frame 179: 0.9963890041044475
# Similarity between frame 179 and frame 180: 0.9911082404536858
# Similarity between frame 180 and frame 181: 0.9947034475663589
# Similarity between frame 181 and frame 182: 0.9977400541898981
# Similarity between frame 182 and frame 183: 0.995346839504877
# Similarity between frame 183 and frame 184: 0.9941321103531461
# Similarity between frame 184 and frame 185: 0.9933089592147828
# Similarity between frame 185 and frame 186: 0.996887534736815
# Similarity between frame 186 and frame 187: 0.9956952656508019
# Similarity between frame 187 and frame 188: 0.9958771056296036
# Similarity between frame 188 and frame 189: 0.9929838179573879
# Similarity between frame 189 and frame 190: 0.9965720814256817
# Similarity between frame 190 and frame 191: 0.996004511727629
# Similarity between frame 191 and frame 192: 0.9961320422509554
# Similarity between frame 192 and frame 193: 0.9933216896107946
# Similarity between frame 193 and frame 194: 0.9962313596968495
# Similarity between frame 194 and frame 195: 0.996022075453776
# Similarity between frame 195 and frame 196: 0.9956837630790821
# Similarity between frame 196 and frame 197: 0.9939938614327535
# Similarity between frame 197 and frame 198: 0.9969288287650852
# Similarity between frame 198 and frame 199: 0.9959565956009719
# Similarity between frame 199 and frame 200: 0.9955201128523626
# Similarity between frame 200 and frame 201: 0.9945672627807276
# Similarity between frame 201 and frame 202: 0.9965128378710447
# Similarity between frame 202 and frame 203: 0.9963776360042111
# Similarity between frame 203 and frame 204: 0.9959951067976831
# Similarity between frame 204 and frame 205: 0.99470526316431
# Similarity between frame 205 and frame 206: 0.9965486579199999
# Similarity between frame 206 and frame 207: 0.9960739489101418
# Similarity between frame 207 and frame 208: 0.9960159770182111
# Similarity between frame 208 and frame 209: 0.9952617707694548
# Similarity between frame 209 and frame 210: 0.9944961923044506
# Similarity between frame 210 and frame 211: 0.9980101532454294
# Similarity between frame 211 and frame 212: 0.9969402933318768
# Similarity between frame 212 and frame 213: 0.9944486305930347
# Similarity between frame 213 and frame 214: 0.9966739269913942
# Similarity between frame 214 and frame 215: 0.9961095362189848
# Similarity between frame 215 and frame 216: 0.9943774150123614
# Similarity between frame 216 and frame 217: 0.9931823179166686
# Similarity between frame 217 and frame 218: 0.9961262296887086
# Similarity between frame 218 and frame 219: 0.9956923988994667
# Similarity between frame 219 and frame 220: 0.9946703332887566
# Similarity between frame 220 and frame 221: 0.9938803819189806
# Similarity between frame 221 and frame 222: 0.9958727423710129
# Similarity between frame 222 and frame 223: 0.9969663921560203
# Similarity between frame 223 and frame 224: 0.9955802883010211
# Similarity between frame 224 and frame 225: 0.9960887202689624
# Similarity between frame 225 and frame 226: 0.9962772540535546
# Similarity between frame 226 and frame 227: 0.9965956620875457
# Similarity between frame 227 and frame 228: 0.9909203661147665
# Similarity between frame 228 and frame 229: 0.9950131665511353
# Similarity between frame 229 and frame 230: 0.9959168821745503
# Similarity between frame 230 and frame 231: 0.9957971923111263
# Similarity between frame 231 and frame 232: 0.9943885147891109
# Similarity between frame 232 and frame 233: 0.9946836808027959
# Similarity between frame 233 and frame 234: 0.9962452414980447
# Similarity between frame 234 and frame 235: 0.9957672760864128
# Similarity between frame 235 and frame 236: 0.9942923562459293
# Similarity between frame 236 and frame 237: 0.9952890850150309
# Similarity between frame 237 and frame 238: 0.9956476592325095
# Similarity between frame 238 and frame 239: 0.9948677117257837
# Similarity between frame 239 and frame 240: 0.995388229789155
# Similarity between frame 240 and frame 241: 0.9972199208608742
# Similarity between frame 241 and frame 242: 0.9962905277415174
# Similarity between frame 242 and frame 243: 0.9948110547415947
# Similarity between frame 243 and frame 244: 0.9963071115376168
# Similarity between frame 244 and frame 245: 0.9965851150292279
# Similarity between frame 245 and frame 246: 0.9956978380582151
# Similarity between frame 246 and frame 247: 0.9948190788613346
# Similarity between frame 247 and frame 248: 0.9961630597585367
# Similarity between frame 248 and frame 249: 0.9963684489849358
# Similarity between frame 249 and frame 250: 0.995162598876266
# Similarity between frame 250 and frame 251: 0.9931133527050742
# Similarity between frame 251 and frame 252: 0.9958014666447237
# Similarity between frame 252 and frame 253: 0.995553409379942
# Similarity between frame 253 and frame 254: 0.9936829492528337
# Similarity between frame 254 and frame 255: 0.9923176402357867
# Similarity between frame 255 and frame 256: 0.9950918641055846
# Similarity between frame 256 and frame 257: 0.9968000946081237
# Similarity between frame 257 and frame 258: 0.9963930530531899
# Similarity between frame 258 and frame 259: 0.9934839622340375
# Similarity between frame 259 and frame 260: 0.9959985588397842
# Similarity between frame 260 and frame 261: 0.9964743316340378
# Similarity between frame 261 and frame 262: 0.9950201322865808
# Similarity between frame 262 and frame 263: 0.9953438165241446
# Similarity between frame 263 and frame 264: 0.9963731888712637
# Similarity between frame 264 and frame 265: 0.9962745595456363
# Similarity between frame 265 and frame 266: 0.9961347619619306
# Similarity between frame 266 and frame 267: 0.9946896734558975
# Similarity between frame 267 and frame 268: 0.9967887355051218
# Similarity between frame 268 and frame 269: 0.9961102202985573
# Similarity between frame 269 and frame 270: 0.9896898079074685
# Similarity between frame 270 and frame 271: 0.9962907480717049
# Similarity between frame 271 and frame 272: 0.996997521501092
# Similarity between frame 272 and frame 273: 0.9961204364517079
# Similarity between frame 273 and frame 274: 0.9946187585086752
# Similarity between frame 274 and frame 275: 0.9951869559559374
# Similarity between frame 275 and frame 276: 0.9953262805038802
# Similarity between frame 276 and frame 277: 0.9938249434390282
# Similarity between frame 277 and frame 278: 0.993871279248623
# Similarity between frame 278 and frame 279: 0.9935919325828685
# Similarity between frame 279 and frame 280: 0.9923770403394888
# Similarity between frame 280 and frame 281: 0.994607338938078
# Similarity between frame 281 and frame 282: 0.996071441590105
# Similarity between frame 282 and frame 283: 0.9936784364874737
# Similarity between frame 283 and frame 284: 0.9960779327599594
# Similarity between frame 284 and frame 285: 0.9962638003504575
# Similarity between frame 285 and frame 286: 0.994516453685064
# Similarity between frame 286 and frame 287: 0.9930345910263751
# Similarity between frame 287 and frame 288: 0.9957063035727127
# Similarity between frame 288 and frame 289: 0.9966574502271544
# Similarity between frame 289 and frame 290: 0.9946168824238083
# Similarity between frame 290 and frame 291: 0.9951159483025077
# Similarity between frame 291 and frame 292: 0.9957279172261737
# Similarity between frame 292 and frame 293: 0.9963383419939884
# Similarity between frame 293 and frame 294: 0.995071797317382
# Similarity between frame 294 and frame 295: 0.9950073934540046
# Similarity between frame 295 and frame 296: 0.9961545812948528
# Similarity between frame 296 and frame 297: 0.9961719603615135
# Similarity between frame 297 and frame 298: 0.9958578992310685
# Similarity between frame 298 and frame 299: 0.995717834787935
# Similarity between frame 299 and frame 300: 0.9958718556736961
# Similarity between frame 300 and frame 301: 0.9971825981737927
# Similarity between frame 301 and frame 302: 0.9968928471445385
# Similarity between frame 302 and frame 303: 0.9967079248694749
# Similarity between frame 303 and frame 304: 0.9865993075190534
# Similarity between frame 304 and frame 305: 0.9932581027724625
# Similarity between frame 305 and frame 306: 0.9956413237283854
# Similarity between frame 306 and frame 307: 0.9937331618365801
# Similarity between frame 307 and frame 308: 0.9940086212976099
# Similarity between frame 308 and frame 309: 0.9929205038738137
# Similarity between frame 309 and frame 310: 0.9958347103942649
# Similarity between frame 310 and frame 311: 0.9965882508262563
# Similarity between frame 311 and frame 312: 0.9948047678304149
# Similarity between frame 312 and frame 313: 0.9936389743758859
# Similarity between frame 313 and frame 314: 0.9967227394796787
# Similarity between frame 314 and frame 315: 0.9958506451312392
# Similarity between frame 315 and frame 316: 0.9958775838309258
# Similarity between frame 316 and frame 317: 0.9939994127648824
# Similarity between frame 317 and frame 318: 0.9957691395669852
# Similarity between frame 318 and frame 319: 0.9964200245786782
# Similarity between frame 319 and frame 320: 0.9950153665160264
# Similarity between frame 320 and frame 321: 0.9941043743464426
# Similarity between frame 321 and frame 322: 0.9954594215020252
# Similarity between frame 322 and frame 323: 0.9962684966422877
# Similarity between frame 323 and frame 324: 0.9949891785913596
# Similarity between frame 324 and frame 325: 0.9931738648344307
# Similarity between frame 325 and frame 326: 0.9955523173536193
# Similarity between frame 326 and frame 327: 0.9955140395481799
# Similarity between frame 327 and frame 328: 0.9893849068180051
# Similarity between frame 328 and frame 329: 0.9955494883999686
# Similarity between frame 329 and frame 330: 0.9934447109898878
# Similarity between frame 330 and frame 331: 0.9974717910437528
# Similarity between frame 331 and frame 332: 0.9971240823869614
# Similarity between frame 332 and frame 333: 0.9945017759198107
# Similarity between frame 333 and frame 334: 0.9964722867686129
# Similarity between frame 334 and frame 335: 0.9967942715440804
# Similarity between frame 335 and frame 336: 0.9950837820048215
# Similarity between frame 336 and frame 337: 0.9932929127613929
# Similarity between frame 337 and frame 338: 0.9960367677001069
# Similarity between frame 338 and frame 339: 0.9965135203912734
# Similarity between frame 339 and frame 340: 0.9963672489130706
# Similarity between frame 340 and frame 341: 0.9941993863959102
# Similarity between frame 341 and frame 342: 0.9960549427718578
# Similarity between frame 342 and frame 343: 0.9964114429200027
# Similarity between frame 343 and frame 344: 0.996272821971421
# Similarity between frame 344 and frame 345: 0.9943571439595035
# Similarity between frame 345 and frame 346: 0.9959091562475239
# Similarity between frame 346 and frame 347: 0.9960297902600573
# Similarity between frame 347 and frame 348: 0.9959670885300245
# Similarity between frame 348 and frame 349: 0.9954559528260043
# Similarity between frame 349 and frame 350: 0.9964461426644802
# Similarity between frame 350 and frame 351: 0.9957592128395314
# Similarity between frame 351 and frame 352: 0.9952094397106238
# Similarity between frame 352 and frame 353: 0.9950357632791428
# Similarity between frame 353 and frame 354: 0.9958639081279653
# Similarity between frame 354 and frame 355: 0.9954499094379754
# Similarity between frame 355 and frame 356: 0.9944705652685727
# Similarity between frame 356 and frame 357: 0.9929920416706862
# Similarity between frame 357 and frame 358: 0.9955286478062112
# Similarity between frame 358 and frame 359: 0.9969806056542719
# Similarity between frame 359 and frame 360: 0.9917588719829096
# Similarity between frame 360 and frame 361: 0.9967345244686581
# Similarity between frame 361 and frame 362: 0.9975773636679365
# Similarity between frame 362 and frame 363: 0.9970920102668833
# Similarity between frame 363 and frame 364: 0.9959469901038006
# Similarity between frame 364 and frame 365: 0.9951302878615307
# Similarity between frame 365 and frame 366: 0.9960679100502065
# Similarity between frame 366 and frame 367: 0.9932876478592728
# Similarity between frame 367 and frame 368: 0.9959330891863697
# Similarity between frame 368 and frame 369: 0.996297704588844
# Similarity between frame 369 and frame 370: 0.994415327151814
# Similarity between frame 370 and frame 371: 0.992072008225189
# Similarity between frame 371 and frame 372: 0.9961369437011813
# Similarity between frame 372 and frame 373: 0.9967079129273503
# Similarity between frame 373 and frame 374: 0.9958214134642115
# Similarity between frame 374 and frame 375: 0.9937954966077606
# Similarity between frame 375 and frame 376: 0.9959207704209176
# Similarity between frame 376 and frame 377: 0.9957151017461209
# Similarity between frame 377 and frame 378: 0.9919905401528546
# Similarity between frame 378 and frame 379: 0.9950894611433888
# Similarity between frame 379 and frame 380: 0.9930971058927623
# Similarity between frame 380 and frame 381: 0.9949004620744056
# Similarity between frame 381 and frame 382: 0.9962491058871176
# Similarity between frame 382 and frame 383: 0.9962772211454723
# Similarity between frame 383 and frame 384: 0.9953513020043823
# Similarity between frame 384 and frame 385: 0.9938967720927656
# Similarity between frame 385 and frame 386: 0.9960304065453751
# Similarity between frame 386 and frame 387: 0.9961523495176118
# Similarity between frame 387 and frame 388: 0.9947575292601295
# Similarity between frame 388 and frame 389: 0.9959934563680327
# Similarity between frame 389 and frame 390: 0.9949412208552928
# Similarity between frame 390 and frame 391: 0.9975670499553684
# Similarity between frame 391 and frame 392: 0.9972079976307959
# Similarity between frame 392 and frame 393: 0.9939596256415794
# Similarity between frame 393 and frame 394: 0.9969235886848375
# Similarity between frame 394 and frame 395: 0.9967361058939225
# Similarity between frame 395 and frame 396: 0.9950460160879642
# Similarity between frame 396 and frame 397: 0.9939196680224718
# Similarity between frame 397 and frame 398: 0.995387722380227
# Similarity between frame 398 and frame 399: 0.9961973361385549
# Similarity between frame 399 and frame 400: 0.9952764417719641
# Similarity between frame 400 and frame 401: 0.9935161407633499
# Similarity between frame 401 and frame 402: 0.9956635861791382
# Similarity between frame 402 and frame 403: 0.9957573057275342
# Similarity between frame 403 and frame 404: 0.9952198155167677
# Similarity between frame 404 and frame 405: 0.9951682460504626
# Similarity between frame 405 and frame 406: 0.9964085785442369
# Similarity between frame 406 and frame 407: 0.9966161654726744
# Similarity between frame 407 and frame 408: 0.9958214593693225
# Similarity between frame 408 and frame 409: 0.9944918960734702
# Similarity between frame 409 and frame 410: 0.9962469374044304
# Similarity between frame 410 and frame 411: 0.9962740872304077
# Similarity between frame 411 and frame 412: 0.9958532232723478
# Similarity between frame 412 and frame 413: 0.9942363056062012
# Similarity between frame 413 and frame 414: 0.9962797123139383
# Similarity between frame 414 and frame 415: 0.9962586758404834
# Similarity between frame 415 and frame 416: 0.9943391521503073
# Similarity between frame 416 and frame 417: 0.994057619258018
# Similarity between frame 417 and frame 418: 0.9949737062940174
# Similarity between frame 418 and frame 419: 0.9963073183012608
# Similarity between frame 419 and frame 420: 0.9925633261274931
# Similarity between frame 420 and frame 421: 0.9960611449192684
# Similarity between frame 421 and frame 422: 0.9978591194234184
# Similarity between frame 422 and frame 423: 0.9967033793253663
# Similarity between frame 423 and frame 424: 0.9952346745646843
# Similarity between frame 424 and frame 425: 0.9956028233397254
# Similarity between frame 425 and frame 426: 0.9953631760665149
# Similarity between frame 426 and frame 427: 0.9945403145832016
# Similarity between frame 427 and frame 428: 0.9931705210662102
# Similarity between frame 428 and frame 429: 0.994964586334733
# Similarity between frame 429 and frame 430: 0.9952021772580656
# Similarity between frame 430 and frame 431: 0.9963535084157141
# Similarity between frame 431 and frame 432: 0.9946831852779913
# Similarity between frame 432 and frame 433: 0.9939867265237431
# Similarity between frame 433 and frame 434: 0.9959064246702979
# Similarity between frame 434 and frame 435: 0.9964371585256797
# Similarity between frame 435 and frame 436: 0.9955204340874934
# Similarity between frame 436 and frame 437: 0.9935755482584783
# Similarity between frame 437 and frame 438: 0.9956524911915693
# Similarity between frame 438 and frame 439: 0.9961141147960665
# Similarity between frame 439 and frame 440: 0.9954120540481853
# Similarity between frame 440 and frame 441: 0.9924996253273316
# Similarity between frame 441 and frame 442: 0.9954848051130132
# Similarity between frame 442 and frame 443: 0.9957448690443141
# Similarity between frame 443 and frame 444: 0.9954624678751102
# Similarity between frame 444 and frame 445: 0.9950506529193643
# Similarity between frame 445 and frame 446: 0.9959752096608641
# Similarity between frame 446 and frame 447: 0.9968078234301563
# Similarity between frame 447 and frame 448: 0.995260781846711
# Similarity between frame 448 and frame 449: 0.9951247450851112
# Similarity between frame 449 and frame 450: 0.9942116981314498
# Similarity between frame 450 and frame 451: 0.9981287948427948
# Similarity between frame 451 and frame 452: 0.997760048596384
# Similarity between frame 452 and frame 453: 0.9965088594817564
# Similarity between frame 453 and frame 454: 0.9977923608406292
# Similarity between frame 454 and frame 455: 0.9971237566282768
# Similarity between frame 455 and frame 456: 0.9906414788817116
# Similarity between frame 456 and frame 457: 0.9932604600022226
# Similarity between frame 457 and frame 458: 0.9957181719977394
# Similarity between frame 458 and frame 459: 0.9967952014716074
# Similarity between frame 459 and frame 460: 0.9958151389278598
# Similarity between frame 460 and frame 461: 0.9932450537337808
# Similarity between frame 461 and frame 462: 0.996018389992727
# Similarity between frame 462 and frame 463: 0.9957481185423982
# Similarity between frame 463 and frame 464: 0.9954678637976663
# Similarity between frame 464 and frame 465: 0.9946673606634732
# Similarity between frame 465 and frame 466: 0.9964655264536931
# Similarity between frame 466 and frame 467: 0.9958969631773039
# Similarity between frame 467 and frame 468: 0.9945308611939386
# Similarity between frame 468 and frame 469: 0.9945875705252135
# Similarity between frame 469 and frame 470: 0.9964911581405244
# Similarity between frame 470 and frame 471: 0.9955668143874735
# Similarity between frame 471 and frame 472: 0.9942207188168202
# Similarity between frame 472 and frame 473: 0.9939063051664515
# Similarity between frame 473 and frame 474: 0.9960524374925894
# Similarity between frame 474 and frame 475: 0.9960555884572929
# Similarity between frame 475 and frame 476: 0.9937191286418304
# Similarity between frame 476 and frame 477: 0.9925468920833602
# Similarity between frame 477 and frame 478: 0.9899448439847609
# Similarity between frame 478 and frame 479: 0.9958942308368667
# Similarity between frame 479 and frame 480: 0.9858337766872555
# Similarity between frame 480 and frame 481: 0.9960589773314651
# Similarity between frame 481 and frame 482: 0.9980868520007272
# Similarity between frame 482 and frame 483: 0.9965585240254055
# Similarity between frame 483 and frame 484: 0.995257438703174
# Similarity between frame 484 and frame 485: 0.992278900281359
# Similarity between frame 485 and frame 486: 0.9957588949872535
# Similarity between frame 486 and frame 487: 0.9947407120449026
# Similarity between frame 487 and frame 488: 0.9932342030384086
# Similarity between frame 488 and frame 489: 0.9932049153084164
# Similarity between frame 489 and frame 490: 0.9952516169047931
# Similarity between frame 490 and frame 491: 0.9957642682902634
# Similarity between frame 491 and frame 492: 0.9948761869817851
# Similarity between frame 492 and frame 493: 0.9928563762131544
# Similarity between frame 493 and frame 494: 0.9963483083704052
# Similarity between frame 494 and frame 495: 0.9962323045956536
# Similarity between frame 495 and frame 496: 0.9947704556293325
# Similarity between frame 496 and frame 497: 0.993088577593897
# Similarity between frame 497 and frame 498: 0.995288032504842
# Similarity between frame 498 and frame 499: 0.996327253057314
# Similarity between frame 499 and frame 500: 0.9948029264822761
# Similarity between frame 500 and frame 501: 0.9922105408394261
# Similarity between frame 501 and frame 502: 0.9952343970604857
# Similarity between frame 502 and frame 503: 0.9953438905298673
# Similarity between frame 503 and frame 504: 0.9955605039499252
# Similarity between frame 504 and frame 505: 0.9941980216838227
# Similarity between frame 505 and frame 506: 0.9953708088344582
# Similarity between frame 506 and frame 507: 0.9958904308557953
# Similarity between frame 507 and frame 508: 0.994141127918592
# Similarity between frame 508 and frame 509: 0.9948643609462727
# Similarity between frame 509 and frame 510: 0.9951643343092452
# Similarity between frame 510 and frame 511: 0.9965624870617493
# Similarity between frame 511 and frame 512: 0.9958732411933547
# Similarity between frame 512 and frame 513: 0.9929208632651086
# Similarity between frame 513 and frame 514: 0.9955884078818072
# Similarity between frame 514 and frame 515: 0.9955321534480027
# Similarity between frame 515 and frame 516: 0.9938560543696775
# Similarity between frame 516 and frame 517: 0.9953351689776438
# Similarity between frame 517 and frame 518: 0.9936589805335573
# Similarity between frame 518 and frame 519: 0.9945225516777827
# Similarity between frame 519 and frame 520: 0.9945948245416049
# Similarity between frame 520 and frame 521: 0.9939082330071127
# Similarity between frame 521 and frame 522: 0.9955052667321606
# Similarity between frame 522 and frame 523: 0.9945521570921456
# Similarity between frame 523 and frame 524: 0.9938770589259175
# Similarity between frame 524 and frame 525: 0.9948587843561822
# Similarity between frame 525 and frame 526: 0.9957993615375752
# Similarity between frame 526 and frame 527: 0.9951355907304831
# Similarity between frame 527 and frame 528: 0.9902889309400191
# Similarity between frame 528 and frame 529: 0.9960206981372934
# Similarity between frame 529 and frame 530: 0.9960139614141037
# Similarity between frame 530 and frame 531: 0.9966631425500908
# Similarity between frame 531 and frame 532: 0.9937259197758233
# Similarity between frame 532 and frame 533: 0.9955641194842406
# Similarity between frame 533 and frame 534: 0.9965595342535154
# Similarity between frame 534 and frame 535: 0.9964428556870066
# Similarity between frame 535 and frame 536: 0.9954512180810096
# Similarity between frame 536 and frame 537: 0.9952234075042082
# Similarity between frame 537 and frame 538: 0.9961314914395784
# Similarity between frame 538 and frame 539: 0.9958994979299636
# Similarity between frame 539 and frame 540: 0.992920416374017
# Similarity between frame 540 and frame 541: 0.9970690983328974
# Similarity between frame 541 and frame 542: 0.9970367637801573
# Similarity between frame 542 and frame 543: 0.9961732300058721
# Top 5 scene cut frames (by least similarity):
# Scene cut 1: between frame 4 and frame 5 with similarity score: 0.9638997884708354
# <PIL.Image.Image image mode=RGB size=320x240>
# <PIL.Image.Image image mode=RGB size=320x240>
# Scene cut 2: between frame 12 and frame 13 with similarity score: 0.980645297751961
# <PIL.Image.Image image mode=RGB size=320x240>
# <PIL.Image.Image image mode=RGB size=320x240>
# Scene cut 3: between frame 479 and frame 480 with similarity score: 0.9858337766872555
# <PIL.Image.Image image mode=RGB size=320x240>
# <PIL.Image.Image image mode=RGB size=320x240>
# Scene cut 4: between frame 16 and frame 17 with similarity score: 0.9862250274084435
# <PIL.Image.Image image mode=RGB size=320x240>
# <PIL.Image.Image image mode=RGB size=320x240>
# Scene cut 5: between frame 303 and frame 304 with similarity score: 0.9865993075190534
# <PIL.Image.Image image mode=RGB size=320x240>
# <PIL.Image.Image image mode=RGB size=320x240>
